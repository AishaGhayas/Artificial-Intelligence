# %% [markdown]
# ## data wargling(joining)
# - df.merge()
# - df.join()
# - df.concat()
#
# ## groupby
# ## handling missing values

# %%
import numpy as np
import pandas as pd

# %%
df1 =  pd.DataFrame({"cnic": np.random.randint(1,20, size = 20),
                    "acc": np.random.randint(1,5, size = (20)),
                    })
df1
# Out:
#     cnic  acc
# 0     12    3
# 1     17    1
# 2     18    3
# 3     14    1
# 4     11    2
# 5     17    2
# 6     13    3
# 7      5    1
# 8      8    4
# 9     11    4
# 10    10    1
# 11     5    1
# 12    12    3
# 13     9    4
# 14    14    1
# 15    19    1
# 16    17    4
# 17    14    4
# 18     2    1
# 19    11    3

# %%
df2 =  pd.DataFrame({"cnic": np.random.randint(1,20, size = 20),
                    "acc": np.random.randint(1,5, size = 20),
                    "mob_no": np.random.randint(2000334,3345645, size = 20),
                    "DOB":pd.date_range("1998-01-01", periods=20, freq="Y"),
                    "name": [chr(x) for x in np.random.randint(65,91, size = 20)],
                    "gender": np.random.choice(["M", "F"], size = 20)
                    })
df2
# Out:
#     cnic  acc   mob_no        DOB name gender
# 0      9    3  3143734 1998-12-31    Y      M
# 1     10    1  2754361 1999-12-31    W      F
# 2      1    4  2660356 2000-12-31    P      F
# 3      9    2  2677311 2001-12-31    C      M
# 4      3    1  3270792 2002-12-31    A      F
# 5     16    2  2141206 2003-12-31    V      M
# 6      3    4  2107178 2004-12-31    C      F
# 7      3    2  2244989 2005-12-31    N      F
# 8     12    2  2341726 2006-12-31    W      M
# 9     15    2  2567584 2007-12-31    G      M
# 10    13    3  2587170 2008-12-31    I      M
# 11     6    4  2548640 2009-12-31    A      F
# 12     7    4  2086203 2010-12-31    B      M
# 13     5    1  2918060 2011-12-31    O      M
# 14     9    1  3270306 2012-12-31    I      M
# 15    18    3  2659353 2013-12-31    J      M
# 16    14    4  3182838 2014-12-31    S      M
# 17     8    1  2063575 2015-12-31    X      F
# 18     9    3  3237066 2016-12-31    U      M
# 19    16    4  2553867 2017-12-31    Z      M

# %%
#data_frame_left.merge(dataframe_right, on = "colom name same in both", how = "type of join")
#type of join = inner, outer, left, right

#data_frame_left.merge(dataframe_right, on = [col1, col2, col3], how = "type of join")

#if column name different in both tables

#data_frame_left.merge(dataframe_right, left_on = "col", right_on = "col", how = "type of join")
#data_frame_left.merge(dataframe_right, left_index = True, right_index = False, how = "type of join")

# %%
#datatype and pattern should be same for PK in both tables

print(df1.dtypes, df2.dtypes, sep = "\n\n\n")
# Out:
# cnic    int32
# acc     int32
# dtype: object
#
#
# cnic               int32
# acc                int32
# mob_no             int32
# DOB       datetime64[ns]
# name              object
# gender            object
# dtype: object

# %%
#data_frame_left.merge(dataframe_right, on = "colom name same in both", how = "type of join")
a = df1.merge(df2, on="cnic", how="inner") #return only those rows having same cnic values in both
a
# Out:
#     cnic  acc_x  acc_y   mob_no        DOB name gender
# 0     12      3      2  2341726 2006-12-31    W      M
# 1     12      3      2  2341726 2006-12-31    W      M
# 2     18      3      3  2659353 2013-12-31    J      M
# 3     14      1      4  3182838 2014-12-31    S      M
# 4     14      1      4  3182838 2014-12-31    S      M
# 5     14      4      4  3182838 2014-12-31    S      M
# 6     13      3      3  2587170 2008-12-31    I      M
# 7      5      1      1  2918060 2011-12-31    O      M
# 8      5      1      1  2918060 2011-12-31    O      M
# 9      8      4      1  2063575 2015-12-31    X      F
# 10    10      1      1  2754361 1999-12-31    W      F
# 11     9      4      3  3143734 1998-12-31    Y      M
# 12     9      4      2  2677311 2001-12-31    C      M
# 13     9      4      1  3270306 2012-12-31    I      M
# 14     9      4      3  3237066 2016-12-31    U      M

# %%
#data_frame_left.merge(dataframe_right, on = [col1, col2, col3], how = "type of join")
a = df1.merge(df2, on= ["cnic", "acc"], how = "inner") #return only those rows having same cnic and acc values
a
# Out:
#    cnic  acc   mob_no        DOB name gender
# 0    18    3  2659353 2013-12-31    J      M
# 1    13    3  2587170 2008-12-31    I      M
# 2     5    1  2918060 2011-12-31    O      M
# 3     5    1  2918060 2011-12-31    O      M
# 4    10    1  2754361 1999-12-31    W      F
# 5    14    4  3182838 2014-12-31    S      M

# %%
df1.columns
# Out:
# Index(['cnic', 'acc'], dtype='object')

# %%
df1.columns = ['Cust_CNIC', 'account_no'] #updated col names
df1.head(2)
# Out:
#    Cust_CNIC  account_no
# 0         12           3
# 1         17           1

# %%
df2.columns
# Out:
# Index(['cnic', 'acc', 'mob_no', 'DOB', 'name', 'gender'], dtype='object')

# %% [markdown]
# ### if column name different in both tables
#
# #### data_frame_left.merge(dataframe_right, left_on = "col", right_on = "col", how = "type of join")

# %%
a = df1.merge(df2, left_on="Cust_CNIC", right_on="cnic") #how = inner by default
a
# Out:
#     Cust_CNIC  account_no  cnic  acc   mob_no        DOB name gender
# 0          12           3    12    2  2341726 2006-12-31    W      M
# 1          12           3    12    2  2341726 2006-12-31    W      M
# 2          18           3    18    3  2659353 2013-12-31    J      M
# 3          14           1    14    4  3182838 2014-12-31    S      M
# 4          14           1    14    4  3182838 2014-12-31    S      M
# 5          14           4    14    4  3182838 2014-12-31    S      M
# 6          13           3    13    3  2587170 2008-12-31    I      M
# 7           5           1     5    1  2918060 2011-12-31    O      M
# 8           5           1     5    1  2918060 2011-12-31    O      M
# 9           8           4     8    1  2063575 2015-12-31    X      F
# 10         10           1    10    1  2754361 1999-12-31    W      F
# 11          9           4     9    3  3143734 1998-12-31    Y      M
# 12          9           4     9    2  2677311 2001-12-31    C      M
# 13          9           4     9    1  3270306 2012-12-31    I      M
# 14          9           4     9    3  3237066 2016-12-31    U      M

# %%
a = df1.merge(df2, left_on=["Cust_CNIC", "account_no"], right_on=["cnic", "acc"]) #how = inner by default
a
# Out:
#    Cust_CNIC  account_no  cnic  acc   mob_no        DOB name gender
# 0         18           3    18    3  2659353 2013-12-31    J      M
# 1         13           3    13    3  2587170 2008-12-31    I      M
# 2          5           1     5    1  2918060 2011-12-31    O      M
# 3          5           1     5    1  2918060 2011-12-31    O      M
# 4         10           1    10    1  2754361 1999-12-31    W      F
# 5         14           4    14    4  3182838 2014-12-31    S      M

# %% [markdown]
# ### join with index

# %%
customers = pd.DataFrame({"CNIC": [14,6,19], "name":["A","B","C"]})

transactions = pd.DataFrame({"cnic": np.random.choice([14,6,19,21], size = 20),
                             "trans_ID": np.random.randint(1,2, size = 20),
                             "trans_Date": pd.date_range("1990-01-01", periods=20),
                             "description": np.random.choice(["M","F"], size=20)
                            })
customers
# Out:
#    CNIC name
# 0    14    A
# 1     6    B
# 2    19    C

# %%
transactions
# Out:
#     cnic  trans_ID trans_Date description
# 0     21         1 1990-01-01           M
# 1     21         1 1990-01-02           M
# 2     19         1 1990-01-03           M
# 3     21         1 1990-01-04           M
# 4     21         1 1990-01-05           F
# 5     19         1 1990-01-06           F
# 6      6         1 1990-01-07           M
# 7     21         1 1990-01-08           F
# 8     19         1 1990-01-09           F
# 9     19         1 1990-01-10           F
# 10     6         1 1990-01-11           F
# 11    21         1 1990-01-12           F
# 12    19         1 1990-01-13           M
# 13    19         1 1990-01-14           M
# 14    19         1 1990-01-15           F
# 15    21         1 1990-01-16           F
# 16    14         1 1990-01-17           F
# 17    21         1 1990-01-18           M
# 18    19         1 1990-01-19           M
# 19    21         1 1990-01-20           M

# %%
customers.merge(transactions, left_on="CNIC", right_on="cnic" )
# Out:
#     CNIC name  cnic  trans_ID trans_Date description
# 0     14    A    14         1 1990-01-17           F
# 1      6    B     6         1 1990-01-07           M
# 2      6    B     6         1 1990-01-11           F
# 3     19    C    19         1 1990-01-03           M
# 4     19    C    19         1 1990-01-06           F
# 5     19    C    19         1 1990-01-09           F
# 6     19    C    19         1 1990-01-10           F
# 7     19    C    19         1 1990-01-13           M
# 8     19    C    19         1 1990-01-14           M
# 9     19    C    19         1 1990-01-15           F
# 10    19    C    19         1 1990-01-19           M

# %%
c = transactions.cnic.value_counts()
c
# Out:
# 21    9
# 19    8
# 6     2
# 14    1
# Name: cnic, dtype: int64

# %%
transactions.cnic.value_counts().index
# Out:
# Int64Index([21, 19, 6, 14], dtype='int64')

# %%
transactions.cnic.value_counts().values
# Out:
# array([9, 8, 2, 1], dtype=int64)

# %%
a = customers.merge(c, left_on="CNIC", right_index=True)
a
# Out:
#    CNIC name  cnic
# 0    14    A     1
# 1     6    B     2
# 2    19    C     8

# %%
a.columns
# Out:
# Index(['CNIC', 'name', 'cnic'], dtype='object')

# %%
a.columns = ['CNIC', 'name', 'trans counts']
a
# Out:
#    CNIC name  trans counts
# 0    14    A             1
# 1     6    B             2
# 2    19    C             8

# %%
customers.join??

# %%
df1 =  pd.DataFrame({"cnic": np.random.randint(1,20, size = 5),
                    "acc": np.random.randint(1,5, size = (5)),
                    })
df2 =  pd.DataFrame({"cnic": np.random.randint(1,20, size = 20),
                    "acc": np.random.randint(1,5, size = 20),
                    "mob_no": np.random.randint(2000334,3345645, size = 20),
                    "DOB":pd.date_range("1998-01-01", periods=20),
                    "name": [chr(x) for x in np.random.randint(65,91, size = 20)],
                    "gender": np.random.choice(["M", "F"], size = 20)
                    })
print(df1)
df2
# Out:
#    cnic  acc
# 0    15    2
# 1     2    2
# 2    10    2
# 3    16    3
# 4     5    1
#     cnic  acc   mob_no        DOB name gender
# 0     11    4  2106861 1998-01-01    N      F
# 1      8    2  2975264 1998-01-02    B      M
# 2     11    3  2730928 1998-01-03    Z      F
# 3      9    3  2925697 1998-01-04    J      M
# 4      1    1  3101337 1998-01-05    I      M
# 5     14    2  3039619 1998-01-06    G      F
# 6     15    1  3061799 1998-01-07    L      M
# 7     14    4  3245676 1998-01-08    Y      F
# 8      3    2  2764042 1998-01-09    X      M
# 9     18    4  2863162 1998-01-10    D      M
# 10     4    4  2829257 1998-01-11    L      F
# 11     4    3  2585650 1998-01-12    M      M
# 12     4    2  2856970 1998-01-13    D      M
# 13     6    2  2237937 1998-01-14    W      F
# 14     2    4  2663700 1998-01-15    O      M
# 15    16    2  2509621 1998-01-16    N      M
# 16    12    4  2751372 1998-01-17    J      M
# 17     9    3  2341109 1998-01-18    P      M
# 18    15    4  2494463 1998-01-19    U      F
# 19    19    3  2272476 1998-01-20    D      F

# %%
df1.join(df2, on = "cnic", how = "left", lsuffix = "_df1")
# Out:
#    cnic_df1  acc_df1  cnic  acc   mob_no        DOB name gender
# 0        12        1    12    2  2930242 2010-12-31    M      F
# 1         6        1     3    2  2877075 2004-12-31    G      F
# 2        16        4    14    1  2960817 2014-12-31    I      F
# 3        18        1     5    4  2013195 2016-12-31    Y      F
# 4        17        1     6    4  2131233 2015-12-31    I      F

# %%
df1.merge(df2, on = "cnic", how = "left")
# Out:
#    cnic  acc_x  acc_y     mob_no        DOB name gender
# 0    12      1    2.0  2930242.0 2010-12-31    M      F
# 1     6      1    4.0  2131233.0 2015-12-31    I      F
# 2    16      4    NaN        NaN        NaT  NaN    NaN
# 3    18      1    3.0  3181996.0 1999-12-31    S      F
# 4    18      1    4.0  2407282.0 2001-12-31    N      M
# 5    17      1    NaN        NaN        NaT  NaN    NaN

# %%
df1.merge(df2, on = "cnic", how = "inner")
# Out:
#    cnic  acc_x  acc_y   mob_no        DOB name gender
# 0    12      1      2  2930242 2010-12-31    M      F
# 1     6      1      4  2131233 2015-12-31    I      F
# 2    18      1      3  3181996 1999-12-31    S      F
# 3    18      1      4  2407282 2001-12-31    N      M

# %%
df1.merge(df2, on = "cnic", how = "outer")
# Out:
#     cnic  acc_x  acc_y     mob_no        DOB name gender
# 0     12    1.0    2.0  2930242.0 2010-12-31    M      F
# 1      6    1.0    4.0  2131233.0 2015-12-31    I      F
# 2     16    4.0    NaN        NaN        NaT  NaN    NaN
# 3     18    1.0    3.0  3181996.0 1999-12-31    S      F
# 4     18    1.0    4.0  2407282.0 2001-12-31    N      M
# 5     17    1.0    NaN        NaN        NaT  NaN    NaN
# 6     10    NaN    4.0  2386312.0 1998-12-31    T      F
# 7     10    NaN    1.0  2111497.0 2009-12-31    D      F
# 8     10    NaN    3.0  2539594.0 2013-12-31    M      M
# 9      8    NaN    2.0  2605824.0 2000-12-31    R      M
# 10     1    NaN    4.0  3132002.0 2002-12-31    P      F
# 11     1    NaN    3.0  2564853.0 2012-12-31    L      M
# 12    14    NaN    2.0  2478243.0 2003-12-31    S      M
# 13    14    NaN    1.0  2960817.0 2014-12-31    I      F
# 14     3    NaN    2.0  2877075.0 2004-12-31    G      F
# 15     3    NaN    3.0  2046134.0 2006-12-31    O      F
# 16    15    NaN    4.0  3344036.0 2005-12-31    F      F
# 17     4    NaN    4.0  2282148.0 2007-12-31    B      F
# 18    19    NaN    3.0  3072766.0 2008-12-31    O      M
# 19     5    NaN    4.0  3315065.0 2011-12-31    B      M
# 20     5    NaN    4.0  2013195.0 2016-12-31    Y      F
# 21     9    NaN    1.0  2763872.0 2017-12-31    A      F

# %%
df1.merge(df2, on = ["cnic","acc"], how = "outer")
# Out:
#     cnic  acc     mob_no        DOB name gender
# 0     12    1        NaN        NaT  NaN    NaN
# 1      6    1        NaN        NaT  NaN    NaN
# 2     16    4        NaN        NaT  NaN    NaN
# 3     18    1        NaN        NaT  NaN    NaN
# 4     17    1        NaN        NaT  NaN    NaN
# 5     10    4  2386312.0 1998-12-31    T      F
# 6     18    3  3181996.0 1999-12-31    S      F
# 7      8    2  2605824.0 2000-12-31    R      M
# 8     18    4  2407282.0 2001-12-31    N      M
# 9      1    4  3132002.0 2002-12-31    P      F
# 10    14    2  2478243.0 2003-12-31    S      M
# 11     3    2  2877075.0 2004-12-31    G      F
# 12    15    4  3344036.0 2005-12-31    F      F
# 13     3    3  2046134.0 2006-12-31    O      F
# 14     4    4  2282148.0 2007-12-31    B      F
# 15    19    3  3072766.0 2008-12-31    O      M
# 16    10    1  2111497.0 2009-12-31    D      F
# 17    12    2  2930242.0 2010-12-31    M      F
# 18     5    4  3315065.0 2011-12-31    B      M
# 19     5    4  2013195.0 2016-12-31    Y      F
# 20     1    3  2564853.0 2012-12-31    L      M
# 21    10    3  2539594.0 2013-12-31    M      M
# 22    14    1  2960817.0 2014-12-31    I      F
# 23     6    4  2131233.0 2015-12-31    I      F
# 24     9    1  2763872.0 2017-12-31    A      F

# %% [markdown]
# # group by

# %%
#dataframe.groupby(by="").agg(min,max,count....)
#dataframe.groupby(by=[c1,c2,c3]).agg(min,max,count....)
e.g:
    how many male/female--> groupby gender
    how many transactions per cust--> groupby cnic
    how many transactions per M or Y
    multiple col e.g:
        trend of M and F transactions per year(year, gender)
        how many transactions by any customers yearly
        how many transactions by unique customers yearly
slab is category of data

# %%
df2["actual amount"] = np.random.randint(1,10000, size=20)
df2
# Out:
#     cnic  acc   mob_no        DOB name gender  actual amount
# 0     11    4  2106861 1998-01-01    N      F           4175
# 1      8    2  2975264 1998-01-02    B      M            411
# 2     11    3  2730928 1998-01-03    Z      F           6017
# 3      9    3  2925697 1998-01-04    J      M            413
# 4      1    1  3101337 1998-01-05    I      M           3459
# 5     14    2  3039619 1998-01-06    G      F           4549
# 6     15    1  3061799 1998-01-07    L      M           3950
# 7     14    4  3245676 1998-01-08    Y      F           3128
# 8      3    2  2764042 1998-01-09    X      M           7075
# 9     18    4  2863162 1998-01-10    D      M           3760
# 10     4    4  2829257 1998-01-11    L      F           5473
# 11     4    3  2585650 1998-01-12    M      M           8393
# 12     4    2  2856970 1998-01-13    D      M           7771
# 13     6    2  2237937 1998-01-14    W      F           5880
# 14     2    4  2663700 1998-01-15    O      M           8935
# 15    16    2  2509621 1998-01-16    N      M           3861
# 16    12    4  2751372 1998-01-17    J      M           9577
# 17     9    3  2341109 1998-01-18    P      M            823
# 18    15    4  2494463 1998-01-19    U      F           3406
# 19    19    3  2272476 1998-01-20    D      F           6653

# %%
c = df2.groupby("gender").agg("count")
c
# Out:
#         cnic  acc  mob_no  DOB  name  actual amount
# gender
# F          8    8       8    8     8              8
# M         12   12      12   12    12             12

# %%
c = df2.groupby("gender")[["cnic"]].agg(["count", "sum"])
c
# Out:
#         cnic
#        count  sum
# gender
# F          8   94
# M         12  101

# %%
df2.groupby([df2["DOB"].dt.year,"gender"])[["cnic"]].agg(["count"])
# Out:
#              cnic
#             count
# DOB  gender
# 1998 F          8
#      M         12

# %%
df2.groupby(["gender", "acc", "cnic"])[["cnic"]].agg(["count"])
# Out:
#                  cnic
#                 count
# gender acc cnic
# F      2   6        1
#            14       1
#        3   11       1
#            19       1
#        4   4        1
#            11       1
#            14       1
#            15       1
# M      1   1        1
#            15       1
#        2   3        1
#            4        1
#            8        1
#            16       1
#        3   4        1
#            9        2
#        4   2        1
#            12       1
#            18       1

# %%
a = df2.groupby(["gender", "acc", "cnic"])[["actual amount"]].agg(["count","sum"])
a
# Out:
#                 actual amount
#                         count   sum
# gender acc cnic
# F      2   6                1  5880
#            14               1  4549
#        3   11               1  6017
#            19               1  6653
#        4   4                1  5473
#            11               1  4175
#            14               1  3128
#            15               1  3406
# M      1   1                1  3459
#            15               1  3950
#        2   3                1  7075
#            4                1  7771
#            8                1   411
#            16               1  3861
#        3   4                1  8393
#            9                2  1236
#        4   2                1  8935
#            12               1  9577
#            18               1  3760

# %%
a.columns
# Out:
# MultiIndex(levels=[['actual amount'], ['count', 'sum']],
#            codes=[[0, 0], [0, 1]])

# %%
a.columns[1][1]
# Out:
# 'sum'

# %%
a['actual amount'].sum()
# Out:
# count       20
# sum      97709
# dtype: int64

# %%
a['actual amount']["sum"].sum() #df2["actual amount"].sum()
# Out:
# 97709

# %%
p = df2.groupby(["gender","acc"])[["actual amount"]].agg(["count", "sum","min","max"])
p.plot(kind = "bar")
p
# Out:
#            actual amount
#                    count    sum   min   max
# gender acc
# F      2               2  10429  4549  5880
#        3               2  12670  6017  6653
#        4               4  16182  3128  5473
# M      1               2   7409  3459  3950
#        2               4  19118   411  7771
#        3               3   9629   413  8393
#        4               3  22272  3760  9577

# %% [markdown]
# # cut()
#
# # qcut()
#
# * to make slabs

# %%
pd.cut(df2["actual amount"],2)
# Out:
# 0     (401.834, 4994.0]
# 1     (401.834, 4994.0]
# 2      (4994.0, 9577.0]
# 3     (401.834, 4994.0]
# 4     (401.834, 4994.0]
# 5     (401.834, 4994.0]
# 6     (401.834, 4994.0]
# 7     (401.834, 4994.0]
# 8      (4994.0, 9577.0]
# 9     (401.834, 4994.0]
# 10     (4994.0, 9577.0]
# 11     (4994.0, 9577.0]
# 12     (4994.0, 9577.0]
# 13     (4994.0, 9577.0]
# 14     (4994.0, 9577.0]
# 15    (401.834, 4994.0]
# 16     (4994.0, 9577.0]
# 17    (401.834, 4994.0]
# 18    (401.834, 4994.0]
# 19     (4994.0, 9577.0]
# Name: actual amount, dtype: category
# Categories (2, interval[float64]): [(401.834, 4994.0] < (4994.0, 9577.0]]

# %%
pd.cut(df2["actual amount"],4).value_counts()
# Out:
# (2702.5, 4994.0]     8
# (4994.0, 7285.5]     5
# (7285.5, 9577.0]     4
# (401.834, 2702.5]    3
# Name: actual amount, dtype: int64

# %%
pd.cut(df2["actual amount"],[1,2000,4000,6000,8000,10000]).value_counts()
# Out:
# (2000, 4000]     6
# (6000, 8000]     4
# (4000, 6000]     4
# (8000, 10000]    3
# (1, 2000]        3
# Name: actual amount, dtype: int64

# %%
pd.qcut(df2["actual amount"],[0, 0.3, 0.7, 1]).value_counts()
# Out:
# (3669.7, 6207.8]     8
# (6207.8, 9577.0]     6
# (410.999, 3669.7]    6
# Name: actual amount, dtype: int64
